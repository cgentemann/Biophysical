# %% [markdown]
# # Take eddy that collocated to bird data and find complete eddy history
# - Read in collocated bird data
# - Read in AVISO eddy database subset for NPac
# - find unique eddies in bird data
# - find all AVISO eddy for that eddy ID
# - create new dataset with track number and observation number as dims
# - save eddy data into it

# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import pandas as pd
import warnings
# filter some warning messages
warnings.filterwarnings("ignore") 
from geopy.distance import geodesic 
from pyresample.kd_tree import resample_nearest
from scipy import spatial

####################you will need to change some paths here!#####################
#list of input files
#list of input files

filename_aviso='F:/data/project_data/NASA_biophysical/aviso/eddy_trajectory_19930101_20170106.nc'   #From AVISO  website
filename_bird_netcdf='f:/data/project_data/NASA_biophysical/collocated_data/NPPSD_GOA_allseabird_wide_sat_and_eddy_data_final.nc'
#################################################################################
filename_origin='f:/data/project_data/NASA_biophysical/collocated_data/NPPSD_GOA_allseabird_full_eddy_info.nc'

# %% [markdown]
# # read in collocated bird data

# %%
ds_bird = xr.open_dataset(filename_bird_netcdf)
ds_bird
# Out:
# <xarray.Dataset>
# Dimensions:                 (index: 92738)
# Coordinates:
#   * index                   (index) int64 0 1 2 3 4 ... 92734 92735 92736 92737
# Data variables:
#     Unnamed: 0              (index) int64 ...
#     Master.Key              (index) object ...
#     Modified.Platform.Type  (index) object ...
#     Fly.Bird.Method         (index) object ...
#     Year                    (index) int64 ...
#     Month                   (index) int64 ...
#     Day                     (index) int64 ...
#     Julian.Date             (index) int64 ...
#     Sample.Area             (index) float64 ...
#     PI.Credit               (index) object ...
#     lon                     (index) float64 ...
#     lat                     (index) float64 ...
#     ANMU                    (index) int64 ...
#     ARTE                    (index) int64 ...
#     BLKI                    (index) int64 ...
#     BOGU                    (index) int64 ...
#     CAAU                    (index) int64 ...
#     CAGU                    (index) int64 ...
#     COLO                    (index) int64 ...
#     CRAU                    (index) int64 ...
#     DCCO                    (index) int64 ...
#     FTSP                    (index) int64 ...
#     GWGU                    (index) int64 ...
#     HERG                    (index) int64 ...
#     HOPU                    (index) int64 ...
#     LEAU                    (index) int64 ...
#     LESP                    (index) int64 ...
#     MEGU                    (index) int64 ...
#     NOFU                    (index) int64 ...
#     PAAU                    (index) int64 ...
#     PALO                    (index) int64 ...
#     PIGU                    (index) int64 ...
#     RHAU                    (index) int64 ...
#     SAGU                    (index) int64 ...
#     TUPU                    (index) int64 ...
#     WHAU                    (index) int64 ...
#     ALLSH                   (index) int64 ...
#     ALLMU                   (index) int64 ...
#     ALLBRMU                 (index) int64 ...
#     GACO                    (index) int64 ...
#     ALLALB                  (index) int64 ...
#     ALLPE                   (index) int64 ...
#     ALLJA                   (index) int64 ...
#     time                    (index) datetime64[ns] ...
#     amplitude               (index) float32 ...
#     cyclonic_type           (index) float64 ...
#     lat_eddy                (index) float32 ...
#     lon_eddy                (index) float32 ...
#     observation_number      (index) float64 ...
#     speed_average           (index) float32 ...
#     speed_radius            (index) float32 ...
#     track                   (index) float64 ...
#     time64                  (index) datetime64[ns] ...
#     save_eddy_distance      (index) float32 ...
#     aviso_adt               (index) float64 ...
#     aviso_sla               (index) float64 ...
#     aviso_ugos              (index) float64 ...
#     aviso_ugosa             (index) float64 ...
#     aviso_vgos              (index) float64 ...
#     aviso_vgosa             (index) float64 ...
#     ccmp_uwnd               (index) float32 ...
#     ccmp_vwnd               (index) float32 ...
#     cmc_sst                 (index) float32 ...
#     ETOPO_depth             (index) float64 ...

# %% [markdown]
# # open aviso eddy dataset

# %%
ds_eddy = xr.open_dataset('F:/data/project_data/NASA_biophysical/aviso/eddy_trajectory_19930101_20170106_northpac.nc')
ilen_eddy = len(ds_eddy.lat)
plt.scatter(ds_eddy.lon,ds_eddy.lat)
ds_eddy
# Out:
# <xarray.Dataset>
# Dimensions:             (obs: 334732)
# Coordinates:
#   * obs                 (obs) int64 0 1 2 3 4 ... 334728 334729 334730 334731
# Data variables:
#     amplitude           (obs) float32 ...
#     cyclonic_type       (obs) float64 ...
#     lat                 (obs) float32 48.0161 47.9866 ... 47.7512 47.7305
#     lon                 (obs) float32 -128.318 -128.357 ... -141.957 -141.965
#     observation_number  (obs) float64 ...
#     speed_average       (obs) float32 ...
#     speed_radius        (obs) float32 ...
#     time                (obs) object ...
#     track               (obs) float64 ...
#     time64              (obs) datetime64[ns] ...
# Attributes:
#     Metadata_Conventions:      Unidata Dataset Discovery v1.0
#     title:                     Mesoscale Eddies in Altimeter Observations of SLA
#     institution:               CNES/CLS in collaboration with Oregon State Un...
#     project:                   SSALTO/DUACS
#     creator_url:               http://www.aviso.altimetry.fr
#     creator_email:             aviso@altimetry.fr
#     license:                   http://www.aviso.altimetry.fr/fileadmin/docume...
#     summary:                   This dataset contains eddy atlas from two-sate...
#     comment:                   Surface product; mesoscale eddies
#     input_product_reference:   https://www.aviso.altimetry.fr/en/data/product...
#     date_created:              2017-09-22T10:20:17Z
#     time_coverage_duration:    P8771D
#     time_coverage_start:       1993-01-01T00:00:00Z
#     time_coverage_end:         2017-01-06T00:00:00Z
#     standard_name_vocabulary:  NetCDF Climate and Forecast (CF) Metadata Conv...
#     product_version:           1.0

# %% [markdown]
# # Create xarray dataset structure to hold data

# %%
ds2 = ds_bird.where(ds_bird.track>1,drop=True)
all_tracks = np.unique(ds2.track.data)
ilen = len(all_tracks)
inum_obs = int(ds_eddy.observation_number.max().data)+1
iobs = np.arange(inum_obs)
print(ilen,inum_obs)
da=xr.DataArray(np.nan*np.empty((ilen,inum_obs), 
                                dtype=str(ds_eddy['amplitude'].dtype)), 
                coords={'track': all_tracks.astype('int'),'observation_number':np.arange(inum_obs)}, 
                dims=('track','observation_number'))
ds_tem = xr.Dataset({'amplitude':da})
for var in ds_eddy:
    if (var!='observation_number') & (var!='track') & (var!='time') & (var!='time64') & (var!='amplitude'):
        da=xr.DataArray(np.nan*np.empty((ilen,inum_obs), 
                                dtype=str(ds_eddy[var].dtype)), 
                coords={'track': all_tracks.astype('int'),'observation_number':np.arange(inum_obs)}, 
                dims=('track','observation_number'))

        ds_tem[var]=da
    if (var=='time64'):
        da=xr.DataArray(np.empty((ilen,inum_obs), 
                                dtype=str(ds_eddy[var].dtype)), 
                coords={'track': all_tracks.astype('int'),'observation_number':np.arange(inum_obs)}, 
                dims=('track','observation_number'))

        ds_tem[var]=da
ds_tem
# Out:
# 765 1331
# <xarray.Dataset>
# Dimensions:             (observation_number: 1331, track: 765)
# Coordinates:
#   * track               (track) int32 4438 4918 5213 ... 270829 270892 271234
#   * observation_number  (observation_number) int32 0 1 2 3 ... 1328 1329 1330
# Data variables:
#     amplitude           (track, observation_number) float32 nan nan ... nan nan
#     cyclonic_type       (track, observation_number) float64 nan nan ... nan nan
#     lat                 (track, observation_number) float32 nan nan ... nan nan
#     lon                 (track, observation_number) float32 nan nan ... nan nan
#     speed_average       (track, observation_number) float32 nan nan ... nan nan
#     speed_radius        (track, observation_number) float32 nan nan ... nan nan
#     time64              (track, observation_number) datetime64[ns] 1970-01-01 ... 1970-01-01

# %% [markdown]
# # go through all unique eddies and save data into structure
# - save variable attributes
# - save global attributes

# %%
for ii,idn in enumerate(ds_tem.track.data):
    subset = ds_eddy.where(ds_eddy.track.astype('int')==idn,drop=True)
    for var in subset:
        if (var!='observation_number') & (var!='track') & (var!='time') & (var!='amplitude'):
            ilen_obs = len(subset.obs)
            ds_tem[var][ii,:ilen_obs]=subset[var][:].data
            ds_tem[var].attrs=subset[var].attrs
    if subset.observation_number[0].data>0:
        print(ii,subset.observation_number[0])
ds_tem.attrs = ds_eddy.attrs
ds_tem.to_netcdf(filename_origin)
# Out:
# 0 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 3276
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 1 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 3854
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 2 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 3945
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 3 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 4298
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 4 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 4523
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 5 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 5414
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 6 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 5485
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 7 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 5658
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 8 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 5696
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 9 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 6789
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 10 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 7079
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 11 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 8641
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 12 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 9568
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 13 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 13268
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 14 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 14061
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 15 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 15433
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 16 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 16933
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 17 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 17667
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 18 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 17737
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 19 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 17983
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 20 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 18115
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 21 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 19005
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 22 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 19160
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 23 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 20443
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 24 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 25189
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 25 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 25814
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 26 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 25996
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 27 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 26536
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 28 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 27432
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 29 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 27470
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 30 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 30247
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 31 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 30440
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 32 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 30952
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 33 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 31857
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 34 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 31957
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 35 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 32412
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 36 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 33056
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 37 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 34017
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 38 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 34402
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 39 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 34904
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 40 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 38682
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 41 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 41268
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 42 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 43191
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 43 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 43429
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 44 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 43771
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 45 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 43895
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 46 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 44059
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 47 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 44614
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 48 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 46309
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 49 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 46488
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 50 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 47147
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 51 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 47284
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 52 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 47464
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 53 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 47493
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 54 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 48114
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 55 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 48204
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 56 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 48322
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 57 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 48466
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 58 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 48518
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 59 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 49140
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 60 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 49240
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 61 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 49279
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 62 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 49567
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 63 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 49635
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 64 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 49850
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 65 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 50656
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 66 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 51337
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 67 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 53702
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 68 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 53794
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 69 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 54250
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 70 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 54375
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 71 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 54682
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 72 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 54813
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 73 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 56161
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 74 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 56353
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 75 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 57797
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 76 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 58021
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 77 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 58056
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 78 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 58332
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 79 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 58602
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 80 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 58717
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 81 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 58819
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 82 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 59089
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 83 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 59166
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 84 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 59765
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 85 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 60260
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 86 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 60548
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 87 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 60860
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 88 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 61139
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 89 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 62364
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 90 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 63121
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 91 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 63320
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 92 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 63374
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 93 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 63498
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 94 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 63612
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 95 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 64147
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 96 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 64917
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 97 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 65146
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 98 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 65425
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 99 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 66108
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 100 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 67695
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 101 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 68638
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 102 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 68800
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 103 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 69073
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 104 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 69217
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 105 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 69463
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 106 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 69737
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 107 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 70607
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 108 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 71090
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 109 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 71362
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 110 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 71431
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 111 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 71459
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 112 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 71530
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 113 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 71590
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 114 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 71842
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 115 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 71905
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 116 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 72317
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 117 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 72745
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 118 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 72823
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 119 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 73287
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 120 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 73393
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 121 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 73675
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 122 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 73762
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 123 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 74124
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 124 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 74906
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 125 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 75105
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 126 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 75510
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 127 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 75614
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 128 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 76183
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 129 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 77179
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 130 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 77985
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 131 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 79905
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 132 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 79975
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 133 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 81318
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 134 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 81389
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 135 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 81528
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 136 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 81917
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 137 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 82033
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 138 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 82118
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 139 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 82868
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 140 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 83250
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 141 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 83433
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 142 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 83933
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 143 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 84216
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 144 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 84564
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 145 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 84668
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 146 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 84765
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 147 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 84951
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 148 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 85071
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 149 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 85429
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 151 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 85601
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 152 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 85939
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 153 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 86259
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 154 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 86370
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 155 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 86878
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 156 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 86919
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 157 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 87179
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 158 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 87213
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 159 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 87395
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 160 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 87504
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 161 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 87756
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 162 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 87918
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 163 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 88305
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 164 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 88646
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 165 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 89026
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 166 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 89379
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 167 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 89600
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 168 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 90236
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 169 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 90439
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 170 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 90629
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 171 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 90902
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 172 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
# ...
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 212 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 109313
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 213 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 111027
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 214 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 111055
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 215 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 111379
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 216 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 111418
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 217 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 111470
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 218 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 111896
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 219 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 111949
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 220 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 111978
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 221 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 112007
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 222 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 112097
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 223 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 112161
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 224 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 112812
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 225 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 112886
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 226 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 112995
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 227 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 113140
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 228 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 113235
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 229 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 113490
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 230 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 113663
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 231 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 114238
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 232 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 114290
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 233 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 114652
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 234 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 115161
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 235 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 116492
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 236 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 116748
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 237 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 117172
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 238 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 117326
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 239 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 117961
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 240 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 118287
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 241 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 119652
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 242 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 121760
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 243 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 121828
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 244 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 121904
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 245 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 122570
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# 246 <xarray.DataArray 'observation_number' ()>
# array(0.)
# Coordinates:
#     obs      int64 123002
# Attributes:
#     Longname:     observation_number
#     description:  observation sequence number, days from eddy start
#     units:        ordinal
#     min:          0
#     max:          2196
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# ~\Miniconda3\envs\satenv\lib\site-packages\xarray\coding\times.py in decode_cf_datetime(num_dates, units, calendar, use_cftime)
#     156         try:
# --> 157             dates = _decode_datetime_with_pandas(flat_num_dates, units, calendar)
#     158         except (OutOfBoundsDatetime, OverflowError):
#
# ~\Miniconda3\envs\satenv\lib\site-packages\xarray\coding\times.py in _decode_datetime_with_pandas(flat_num_dates, units, calendar)
#     104             "Cannot decode times from a non-standard calendar, {!r}, using "
# --> 105             "pandas.".format(calendar)
#     106         )
#
# OutOfBoundsDatetime: Cannot decode times from a non-standard calendar, 'julian', using pandas.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-102-ef5b37688a79> in <module>
#       1 for ii,idn in enumerate(ds_tem.track.data):
# ----> 2     subset = ds_eddy.where(ds_eddy.track.astype('int')==idn,drop=True)
#       3     for var in subset:
#       4         if (var!='observation_number') & (var!='track') & (var!='time') & (var!='amplitude'):
#       5             ilen_obs = len(subset.obs)
#
# ~\Miniconda3\envs\satenv\lib\site-packages\xarray\core\common.py in where(self, cond, other, drop)
#    1130
#    1131             # align so we can use integer indexing
# -> 1132             self, cond = align(self, cond)
#    1133
#    1134             # get cond with the minimal size needed for the Dataset
#
# ~\Miniconda3\envs\satenv\lib\site-packages\xarray\core\alignment.py in align(join, copy, indexes, exclude, fill_value, *objects)
#     327         if not valid_indexers:
#     328             # fast path for no reindexing necessary
# --> 329             new_obj = obj.copy(deep=copy)
#     330         else:
#     331             new_obj = obj.reindex(copy=copy, fill_value=fill_value, **valid_indexers)
#
# ~\Miniconda3\envs\satenv\lib\site-packages\xarray\core\dataset.py in copy(self, deep, data)
#    1071         """
#    1072         if data is None:
# -> 1073             variables = {k: v.copy(deep=deep) for k, v in self._variables.items()}
#    1074         elif not utils.is_dict_like(data):
#    1075             raise ValueError("Data must be dict-like")
#
# ~\Miniconda3\envs\satenv\lib\site-packages\xarray\core\dataset.py in <dictcomp>(.0)
#    1071         """
#    1072         if data is None:
# -> 1073             variables = {k: v.copy(deep=deep) for k, v in self._variables.items()}
#    1074         elif not utils.is_dict_like(data):
#    1075             raise ValueError("Data must be dict-like")
#
# ~\Miniconda3\envs\satenv\lib\site-packages\xarray\core\variable.py in copy(self, deep, data)
#     883                 elif not isinstance(data, PandasIndexAdapter):
#     884                     # pandas.Index is immutable
# --> 885                     data = np.array(data)
#     886         else:
#     887             data = as_compatible_data(data)
#
# ~\Miniconda3\envs\satenv\lib\site-packages\xarray\core\indexing.py in __array__(self, dtype)
#     675
#     676     def __array__(self, dtype=None):
# --> 677         self._ensure_cached()
#     678         return np.asarray(self.array, dtype=dtype)
#     679
#
# ~\Miniconda3\envs\satenv\lib\site-packages\xarray\core\indexing.py in _ensure_cached(self)
#     672     def _ensure_cached(self):
#     673         if not isinstance(self.array, NumpyIndexingAdapter):
# --> 674             self.array = NumpyIndexingAdapter(np.asarray(self.array))
#     675
#     676     def __array__(self, dtype=None):
#
# ~\Miniconda3\envs\satenv\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ~\Miniconda3\envs\satenv\lib\site-packages\xarray\core\indexing.py in __array__(self, dtype)
#     651
#     652     def __array__(self, dtype=None):
# --> 653         return np.asarray(self.array, dtype=dtype)
#     654
#     655     def __getitem__(self, key):
#
# ~\Miniconda3\envs\satenv\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ~\Miniconda3\envs\satenv\lib\site-packages\xarray\core\indexing.py in __array__(self, dtype)
#     555     def __array__(self, dtype=None):
#     556         array = as_indexable(self.array)
# --> 557         return np.asarray(array[self.key], dtype=None)
#     558
#     559     def transpose(self, order):
#
# ~\Miniconda3\envs\satenv\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ~\Miniconda3\envs\satenv\lib\site-packages\xarray\coding\variables.py in __array__(self, dtype)
#      70
#      71     def __array__(self, dtype=None):
# ---> 72         return self.func(self.array)
#      73
#      74     def __repr__(self):
#
# ~\Miniconda3\envs\satenv\lib\site-packages\xarray\coding\times.py in decode_cf_datetime(num_dates, units, calendar, use_cftime)
#     158         except (OutOfBoundsDatetime, OverflowError):
#     159             dates = _decode_datetime_with_cftime(
# --> 160                 flat_num_dates.astype(np.float), units, calendar
#     161             )
#     162
#
# ~\Miniconda3\envs\satenv\lib\site-packages\xarray\coding\times.py in _decode_datetime_with_cftime(num_dates, units, calendar)
#      95
#      96     return np.asarray(
# ---> 97         cftime.num2date(num_dates, units, calendar, only_use_cftime_datetimes=True)
#      98     )
#      99
#
# cftime\_cftime.pyx in cftime._cftime.num2date()
#
# cftime\_cftime.pyx in cftime._cftime.utime.num2date()
#
# cftime\_cftime.pyx in cftime._cftime.DateFromJulianDay()
#
# cftime\_cftime.pyx in cftime._cftime.DateFromJulianDay.getdateinfo()
#
# <__array_function__ internals> in clip(*args, **kwargs)
#
# KeyboardInterrupt:
