# %%
#make sure you are in gis-env to run this code
#try to read in gis files
import shapefile
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import matplotlib
import matplotlib.pyplot as plt
from shapely.geometry import Polygon
import pyproj

# %%
data_dir = 'F:/data/NASA_biophysical/pices_shapefiles/'
shp_file_base = 'PicesRegion11.shp'
df = gpd.read_file(data_dir+shp_file_base)
crs_source = ('+proj=natearth +ellps=GRS80 +unit=m +lon_0=180')
df.crs = crs_source  
df2 = df.to_crs(epsg=4326) 
df2.plot(cmap='Set2', figsize=(10, 10));
plt.savefig('F:/data/NASA_biophysical/pices_shapefiles11.png')

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.head(2)
#world.plot(figsize=(8, 8));
world.plot(ax=df2.plot(cmap='Set2', figsize=(10, 10)), facecolor='gray');
plt.savefig('F:/data/NASA_biophysical/pices_shapefiles11_global.png')

# %%
#old for esri type files.  doesn't work with vector data
sf = shapefile.Reader(data_dir+shp_file_base)
print('number of shapes imported:',len(sf.shapes()))
plt.figure()
ax = plt.axes() # add the axes
ax.set_aspect('equal')

for shape in list(sf.iterShapes()):
    npoints=len(shape.points) # total points
    nparts = len(shape.parts) # total parts

    if nparts == 1:
        x_lon = np.zeros((len(shape.points),1))
        y_lat = np.zeros((len(shape.points),1))
        for ip in range(len(shape.points)):
            x_lon[ip] = shape.points[ip][0]
            y_lat[ip] = shape.points[ip][1]
        plt.plot(x_lon,y_lat)

    else: # loop over parts of each shape, plot separately
        for ip in range(nparts): # loop over parts, plot separately
            i0=shape.parts[ip]
            if ip < nparts-1:
                i1 = shape.parts[ip+1]-1
            else:
                i1 = npoints

        seg=shape.points[i0:i1+1]
        x_lon = np.zeros((len(seg),1))
        y_lat = np.zeros((len(seg),1))
        for ip in range(len(seg)):
            x_lon[ip] = seg[ip][1]
            y_lat[ip] = seg[ip][0]

        plt.plot(x_lon,y_lat)

#plt.xlim(-130,-60)
#plt.ylim(23,50)
plt.show()
# Out:
# number of shapes imported: 1

# %%
sf.encoding
# Out:
# 'utf-8'

# %%
len(sf)
# Out:
# 1

# %%
sf.bbox
# Out:
# [3874276.854800001, 3122126.0632000007, 6140605.9855, 5857677.141100001]

# %%
import geopandas as gpd
data_dir = 'F:/data/NASA_biophysical/pices_shapefiles/'
shp_file_base = 'PicesRegion11.shp'
filename_shp = data_dir+shp_file_base
t = gpd.read_file(data_dir+shp_file_base)
print(t.columns)
# source crs
print(t.crs)
t.head(2)
# Out:
# Index(['OBJECTID_1', 'OBJECTID', 'LME_NUMBER', 'LME_NAME', 'GROUPING',
#        'ARCTIC', 'USLMES', 'Shape_Leng', 'SUM_GIS_KM', 'Shape_Le_1',
#        'Shape_Area', 'geometry'],
#       dtype='object')
# {}
#    OBJECTID_1  OBJECTID  LME_NUMBER        LME_NAME GROUPING ARCTIC USLMES  \
# 0           1         4         2.0  Gulf of Alaska     None   None    Yes
#
#    Shape_Leng    SUM_GIS_KM    Shape_Le_1    Shape_Area  \
# 0   495.47378  1.530668e+06  1.865007e+07  2.078917e+12
#
#                                             geometry
# 0  (POLYGON ((6064202.546100002 3126461.8737, 606...

# %%
# destination crs     
t_wgs84 = t.to_crs({'init': 'epsg:4326'}) 
t_wgs84.hea


d(2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-73-2f2daf062e51> in <module>
#       1 # destination crs
# ----> 2 t_wgs84 = t.to_crs({'init': 'epsg:4326'})
#       3 t_wgs84.head(2)
#
# ~\Miniconda3\lib\site-packages\geopandas\geodataframe.py in to_crs(self, crs, epsg, inplace)
#     441         else:
#     442             df = self.copy()
# --> 443         geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#     444         df.geometry = geom
#     445         df.crs = geom.crs
#
# ~\Miniconda3\lib\site-packages\geopandas\geoseries.py in to_crs(self, crs, epsg)
#     302             except TypeError:
#     303                 raise TypeError('Must set either crs or epsg for output.')
# --> 304         proj_in = pyproj.Proj(self.crs, preserve_units=True)
#     305         proj_out = pyproj.Proj(crs, preserve_units=True)
# ...

# %%
import json
from osgeo import ogr
infile = ogr.Open(data_dir+shp_file_base)
layer = infile.GetLayer()
# crs
spatialRef = layer.GetSpatialRef()
spatialRef.ExportToWkt()
# Out:
# 'PROJCS["Sphere_Natural_Earth",GEOGCS["GCS_Sphere_GRS_1980_Mean_Radius",DATUM["Sphere_GRS_1980_Mean_Radius",SPHEROID["Sphere_GRS_1980_Mean_Radius",6371008.7714,0.0]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Natural_Earth"],PARAMETER["False_Easting",90.0],PARAMETER["False_Northing",90.0],PARAMETER["Central_Meridian",180.0],UNIT["Meter",1.0]]'

# %%
import ogr
path_to_infile = data_dir+shp_file_base 
driver = ogr.GetDriverByName('ESRI Shapefile') 
infile = driver.Open(path_to_infile) 
layer = infile.GetLayer()
# get projected spatial reference
sr = layer.GetSpatialRef()
# get geographic spatial reference 
geogr_sr = sr.CloneGeogCS()
# define reprojection
proj_to_geog = osr.CoordinateTransformation(sr, geogr_sr)
for area in layer: 
    area_shape = area.GetGeometryRef() 
    area_polygon = area_shape.GetGeometryRef(0) 
    # transform coordinates
    area_polygon.Transform(proj_to_geog)
    no_of_polygon_vertices = area_polygon.GetPointCount() 
    for vertex in xrange(no_of_polygon_vertices): 
        lon, lat, z = area_polygon.GetPoint(vertex)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-6dc9f1858849> in <module>
#      14     area_polygon = area_shape.GetGeometryRef(0)
#      15     # transform coordinates
# ---> 16     area_polygon.Transform(proj_to_geog)
#      17     no_of_polygon_vertices = area_polygon.GetPointCount()
#      18     for vertex in xrange(no_of_polygon_vertices):
#
# ~\Miniconda3\lib\site-packages\osgeo\ogr.py in Transform(self, *args)
#    7371         OGRERR_NONE on success or an error code.
#    7372         """
# -> 7373         return _ogr.Geometry_Transform(self, *args)
#    7374
#    7375
#
# TypeError: in method 'Geometry_Transform', argument 2 of type 'OSRCoordinateTransformationShadow *'

# %%
from functools import partial
import pyproj
from shapely.ops import transform

project = partial(
    pyproj.transform,
    pyproj.Proj(init='epsg:4326'), # source coordinate system
    pyproj.Proj(init='epsg:26913')) # destination coordinate system

g2 = transform(project, t)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-cb24642a34d4> in <module>
#       8     pyproj.Proj(init='epsg:26913')) # destination coordinate system
#       9
# ---> 10 g2 = transform(project, t)
#      11
#
# ~\Miniconda3\lib\site-packages\shapely\ops.py in transform(func, geom)
#     219     also satisfy the requirements for `func`.
#     220     """
# --> 221     if geom.is_empty:
#     222         return geom
#     223     if geom.type in ('Point', 'LineString', 'LinearRing', 'Polygon'):
#
# ~\Miniconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ...

# %%
data_dir = 'F:/data/NASA_biophysical/pices_shapefiles/'
filename_prj = 'PicesRegion11.prj'
prjText = open( data_dir+filename_prj, 'r').read()
srs = osr.SpatialReference()
#if ( srs.ImportFromWkt( prjText ) ):
#    return ( False, "error importing .prj information from " + prjPath )
inProjection = pyproj.Proj( srs.ExportToProj4() )
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-91-187a01b25703> in <module>
#       5 #if ( srs.ImportFromWkt( prjText ) ):
#       6 #    return ( False, "error importing .prj information from " + prjPath )
# ----> 7 inProjection = pyproj.Proj( srs.ExportToProj4() )
#
# ~\Miniconda3\lib\site-packages\pyproj\__init__.py in __new__(self, projparams, preserve_units, **kwargs)
#     360         # on case-insensitive filesystems).
#     361         projstring = projstring.replace('EPSG','epsg')
# --> 362         return _proj.Proj.__new__(self, projstring)
#     363
#     364     def __call__(self, *args, **kw):
#
# _proj.pyx in _proj.Proj.__cinit__()
#
# RuntimeError: b'projection not named'

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

map = Basemap(llcrnrlon=-0.5,llcrnrlat=39.8,urcrnrlon=4.,urcrnrlat=43.,
             resolution='i', projection='tmerc', lat_0 = 39.5, lon_0 = 1)

map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='#ddaa66',lake_color='aqua')
map.drawcoastlines()

data_dir = 'F:/data/NASA_biophysical/pices_shapefiles/'
shp_file_base = 'PicesRegion11'
map.readshapefile(data_dir+shp_file_base, 'comarques')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-8d22188df20b> in <module>
#      11 data_dir = 'F:/data/NASA_biophysical/pices_shapefiles/'
#      12 shp_file_base = 'PicesRegion11'
# ---> 13 map.readshapefile(data_dir+shp_file_base, 'comarques')
#      14
#      15 plt.show()
#
# ~\Miniconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in readshapefile(self, shapefile, name, drawbounds, zorder, linewidth, color, antialiased, ax, default_encoding)
#    2185                     lons, lats = list(zip(*verts[indx1:indx2]))
#    2186                     if max(lons) > 721. or min(lons) < -721. or max(lats) > 90.01 or min(lats) < -90.01:
# -> 2187                         raise ValueError(msg)
#    2188                     # if latitude is slightly greater than 90, truncate to 90
# ...

# %%
import geopandas as gpd
data_dir = 'F:/data/NASA_biophysical/pices_shapefiles/'
shp_file_base = 'PicesRegion11.shp'
#pices projection is GCS_WGS_1984
tmp = gpd.GeoDataFrame.from_file(data_dir+shp_file_base)
#tmp.crs = {'init' :'WGS84'}
tmp.crs = {'init' :'epsg:4326'}
tmpWGS84 = tmp.to_crs({'proj':'longlat', 'ellps':'WGS84', 'datum':'WGS84'})
#tmpWGS84.to_file(data_dir+shp_file_base+'.A')

# %%
tmp.geometry.project
# Out:
# <bound method GeoPandasBase.project of 0    (POLYGON ((6064202.546100002 3126461.8737, 606...
# Name: geometry, dtype: object>

# %%
cx =tmp.COORDENADA_X.tolist()
cy =tmp.COORDENADA_Y.tolist()
utm15_wgs84 = pp.Proj(init='epsg:32615')
tmp[['wgs_x', 'wgs_y']] = tmp.apply(lambda row:utm15_wgs84(row['COORDENADA_X'], row['COORDENADA_Y'], inverse=True), axis=1).apply(pd.Series)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-8f36b24df728> in <module>
# ----> 1 cx =tmp.COORDENADA_X.tolist()
#       2 cy =tmp.COORDENADA_Y.tolist()
#       3 utm15_wgs84 = pp.Proj(init='epsg:32615')
#       4 tmp[['wgs_x', 'wgs_y']] = tmp.apply(lambda row:utm15_wgs84(row['COORDENADA_X'], row['COORDENADA_Y'], inverse=True), axis=1).apply(pd.Series)
#
# ~\Miniconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'GeoDataFrame' object has no attribute 'COORDENADA_X'

# %%
from pyproj import Proj, transform
# wisconsing EPSG:32054
# epsg:4326 is for the entire world, wgs 84...not obvious
inProj = Proj(init='epsg:32054', preserve_units=True)
outProj = Proj(init='epsg:4326')
x1,y1 = 2560131.496875003, 406816.434375003
x2,y2 = transform(inProj,outProj,x1,y1)
print (x2,y2)
# Out:
# -87.90273917585117 43.09688741327083

# %%
tmp.head()
# Out:
#    OBJECTID_1  OBJECTID  LME_NUMBER        LME_NAME GROUPING ARCTIC USLMES  \
# 0           1         4         2.0  Gulf of Alaska     None   None    Yes
#
#    Shape_Leng    SUM_GIS_KM    Shape_Le_1    Shape_Area  \
# 0   495.47378  1.530668e+06  1.865007e+07  2.078917e+12
#
#                                             geometry
# 0  (POLYGON ((6064202.546100002 3126461.8737, 606...

# %%
tmp.to_crs(epsg=4326)
# Out:
#    OBJECTID_1  OBJECTID  LME_NUMBER        LME_NAME GROUPING ARCTIC USLMES  \
# 0           1         4         2.0  Gulf of Alaska     None   None    Yes
#
#    Shape_Leng    SUM_GIS_KM    Shape_Le_1    Shape_Area  \
# 0   495.47378  1.530668e+06  1.865007e+07  2.078917e+12
#
#                                             geometry
# 0  (POLYGON ((6064202.546100002 3126461.8737, 606...
