# %%
import xarray as xr
import numpy as np
from math import pi
import datetime as dt
import os
import sys
from os.path import exists
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from datetime import *; from dateutil.relativedelta import *
from scipy.interpolate import make_interp_spline, BSpline
from scipy.signal import savgol_filter
import scipy.ndimage as ndimage
import cartopy.crs as ccrs
import cartopy as cart
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
adir_figs='F:/data/NASA_biophysical/biforcation_figures_chelle/figs/'
adir_data='F:/data/NASA_biophysical/biforcation_figures_chelle/'

#ds = ds.assign_coords(lon=(((ds.lon + 180) % 360) - 180)).sortby('lon').sortby('lat').drop({'year'})
def data_smooth(U):
    z.load()
    U=z.copy()
    V=U.copy()
    V=V.fillna(0)
    VV=ndimage.gaussian_filter(V,sigma=5.0,order=0)

    W=0*U.copy()+1
    W=W.fillna(0)
    #W[np.isnan(U)]=0
    WW=ndimage.gaussian_filter(W,sigma=5.0,order=0)

    Z=VV/WW
    return Z

# %%
filelist=[]
dir_data = 'F:/data/sat_data/aviso/data/'
from pathlib import Path
for filename in Path(dir_data).rglob('*.nc'):
    filelist.append(filename)
ds=xr.open_mfdataset(filelist,combine='nested',concat_dim='time').drop({'ugosa','vgosa','err'}).rename({'latitude':'lat','longitude':'lon'})

#dir_data_oscar = 'F:/data/sat_data/oscar/L4/oscar_third_deg/oscar_vel*.nc'
#ds=xr.open_mfdataset(dir_data_oscar,combine='nested',concat_dim='time').isel(depth=0).drop({'um','vm'}).rename({'latitude':'lat','longitude':'lon'})
#ds = ds.sel(lon=slice(20.0,379.9))
#ds = ds.sortby('lat').drop({'year'})

# %%
#ds=xr.open_dataset(filelist[0]) #,combine='nested',concat_dim='time').isel(depth=0).drop({'um','vm'}).rename({'latitude':'lat','longitude':'lon'})
#ds.adt[0,:,:].plot()

# %%
#ds=xr.open_mfdataset(filelist,combine='nested',concat_dim='time').drop({'ugosa','vgosa','err'}).rename({'latitude':'lat','longitude':'lon'})
#ds=xr.open_dataset(filelist[0]) #,combine='nested',concat_dim='time').isel(depth=0).drop({'um','vm'}).rename({'latitude':'lat','longitude':'lon'})
#ds.adt[0,:,:].plot()

# %%
#plt.figure()
#z=ds2.adt[0,:,:]
#z2=ndimage.gaussian_filter(z,sigma=5,order=0)
#z3=data_smooth(z)
#CS = plt.contour(X,Y,z3,30)

# %%
ds2.time[60]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-abafc096d1bb> in <module>
# ----> 1 ds2.time[60]
#
# NameError: name 'ds2' is not defined

# %%
    plt.figure(figsize=(15,6))
    #testing streamlines
    itime=60
    ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180.))
    ax.add_feature(cart.feature.LAND, zorder=100, edgecolor='k')
    ax.coastlines()
    ds2 = ds2.sel(lon=slice(130,260),lat=slice(20,65))
    X,Y=np.meshgrid(ds2.lon,ds2.lat)
    z=ds2.adt[itime,:,:]
    z3=data_smooth(z)
    z3[np.isnan(z)]=np.nan
    CS = ax.contour(X,Y,z3,90)
    num_levels = len(CS.allsegs)
    maxlat=40
    for ilev in range(num_levels):
        num_segments = len(CS.allsegs[ilev])
        index_save,jndex_save=[],[]
        for iseg in range(num_segments):
            num_pts = len(CS.allsegs[ilev][iseg])
            aseg = CS.allsegs[ilev][iseg]
            ax.plot(aseg[:,0],aseg[:,1],color='grey',transform=ccrs.PlateCarree())
#            if itime==8 and max(aseg[:,1])>45:  #this is to fix a broken contour
#                continue
#            if itime==60 and aseg[1,1]>40:  #this is to fix a broken contour
#                continue
#           if itime==93 and aseg[1,1]>45:  #this is to fix a broken contour
#               continue
#            if itime==100 and aseg[1,1]>45:  #this is to fix a broken contour
#                continue
            if min(aseg[:,0])>180 or max(aseg[:,1])>55:
                continue
            ind = (aseg[:,0]>235) & (aseg[:,0]<240) & (aseg[:,1]<48)
            if any(ind) & (aseg[:,1].max()<51):
                index_save.append(ilev)            
                jndex_save.append(iseg)            
            if any(ind) & any(aseg[:,1]>maxlat) & any(aseg[:,0]<230):
                maxlat=aseg[:,1].max().data
                maxcon=aseg
                print(aseg[1,:])
    ax.plot(maxcon[:,0],maxcon[:,1],'r', transform=ccrs.PlateCarree())
    #ax.plot([235,240],[48,48], transform=ccrs.PlateCarree())
    ax.set_extent([130, 260, 20, 65], crs=ccrs.PlateCarree())
    text=ax.text(225,22,np.datetime_as_string(ds2.time[itime], unit='D'),size=20,transform=ccrs.PlateCarree(),zorder=100)

    gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,linewidth=2, color='gray', alpha=0.5, linestyle='--')
    gl.xlocator = mticker.FixedLocator([140,180,-140,-100])
    gl.ylocator = mticker.FixedLocator(np.arange(20,65,10))
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    gl.xlabel_style = {'size': 15, 'color': 'black'}
    gl.ylabel_style = {'size': 15, 'color': 'black'}

# %%
adir_data='F:/data/NASA_biophysical/biforcation_figures_chelle/'
for irun in range(0,3):
    icnt=0
    if irun==0:
        astr_run='monthly'
        adir_figs='F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/'
        ds2 = ds.resample(time='M',keep_attrs=True).mean(skipna=False)
    if irun==1:
        astr_run='quarterly'
        adir_figs='F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/'
        ds2 = ds.resample(time='QS-DEC',keep_attrs=True).mean(skipna=False)
    if irun==2:
        astr_run='annual'
        adir_figs='F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/'
        ds2 = ds.resample(time='AS-JAN',keep_attrs=True).mean(skipna=False)
    ds2 = ds2.sel(lon=slice(130,260),lat=slice(20,65))
    X,Y=np.meshgrid(ds2.lon,ds2.lat)
    maxcon2=[]
    plt.figure(figsize=(15,6))
    for itime in range(ds2.time.size):
        ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180.))
        ax.add_feature(cart.feature.LAND, zorder=100, edgecolor='k')
        ax.coastlines()
        X,Y=np.meshgrid(ds2.lon,ds2.lat)
        #ds2 = ds2.sel(lon=slice(130,260),lat=slice(20,65))
        z=ds2.adt[itime,:,:]
        z3=data_smooth(z)
        z3[np.isnan(z)]=np.nan
        CS = ax.contour(X,Y,z3,90)
        num_levels = len(CS.allsegs)
        maxlat=40
        for ilev in range(num_levels):
            num_segments = len(CS.allsegs[ilev])
            index_save,jndex_save=[],[]
            for iseg in range(num_segments):
                num_pts = len(CS.allsegs[ilev][iseg])
                aseg = CS.allsegs[ilev][iseg]
                ax.plot(aseg[:,0],aseg[:,1],color='grey',transform=ccrs.PlateCarree())
    #            if itime==8 and max(aseg[:,1])>45:  #this is to fix a broken contour
    #                continue
    #            if itime==60 and aseg[1,1]>40:  #this is to fix a broken contour
    #                continue
    #            if itime==93 and aseg[1,1]>45:  #this is to fix a broken contour
    #                continue
    #            if itime==100 and aseg[1,1]>45:  #this is to fix a broken contour
    #                continue
                if min(aseg[:,0])>180 or max(aseg[:,1])>53:
                    continue
                ind = (aseg[:,0]>235) & (aseg[:,0]<240) & (aseg[:,1]<48)
                if any(ind) & (aseg[:,1].max()<51):
                    index_save.append(ilev)            
                    jndex_save.append(iseg)            
                if any(ind) & any(aseg[:,1]>maxlat) & any(aseg[:,0]<230):
                    maxlat=aseg[:,1].max().data
                    maxcon=aseg
                    print(aseg[1,:])
        ax.plot(maxcon[:,0],maxcon[:,1],'r', transform=ccrs.PlateCarree())
        #ax.plot([235,240],[48,48], transform=ccrs.PlateCarree())
        ax.set_extent([130, 260, 20, 65], crs=ccrs.PlateCarree())
        text=ax.text(225,22,np.datetime_as_string(ds2.time[itime], unit='D'),size=20,transform=ccrs.PlateCarree(),zorder=100)

        gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,linewidth=2, color='gray', alpha=0.5, linestyle='--')
        gl.xlocator = mticker.FixedLocator([140,160,180,-160,-140,-120,-100])
        gl.ylocator = mticker.FixedLocator(np.arange(20,65,10))
        gl.xformatter = LONGITUDE_FORMATTER
        gl.yformatter = LATITUDE_FORMATTER
        gl.xlabel_style = {'size': 15, 'color': 'black'}
        gl.ylabel_style = {'size': 15, 'color': 'black'}
#        fname=adir_figs+str(np.datetime_as_string(ds2.time[itime], unit='D')).zfill(2)+'.png'
        fname=adir_figs+'_tmp'+str(icnt).zfill(4)+'.png'
        icnt+=1
    #    plt.show()
        print(fname)
        plt.savefig(fname) 
        plt.clf()
        maxcon2.append(maxcon)   
    for i in range(ds2.time.size):
        maxcon=maxcon2[i]

        #find values u, ssh, etc... at -165 and -135, this will also save lat
        arr=np.abs(maxcon[:,0]-195)
        result = np.where(arr == np.amin(arr))[0][0]
        tem=ds2.isel(time=itime).sel(lon=maxcon[result,0],lat=maxcon[result,1],method='nearest')
        tem.load()   
        if i==0:
            ds_save165=tem
        else:
            ds_save165=xr.concat([ds_save165,tem],dim='time')

            #find values u, ssh, etc... at -165 and -135, this will also save lat
        arr=np.abs(maxcon[:,0]-225)
        result = np.where(arr == np.amin(arr))[0][0]
        tem=ds2.isel(time=itime).sel(lon=maxcon[result,0],lat=maxcon[result,1],method='nearest')
        tem.load()   
        if i==0:
            ds_save135=tem
        else:
            ds_save135=xr.concat([ds_save135,tem],dim='time')

        dlon=xr.DataArray(maxcon[:,0],dims=('z'),coords={'z':np.arange(len(maxcon))},name='lon')
        dlat=xr.DataArray(maxcon[:,1],dims=('z'),coords={'z':np.arange(len(maxcon))},name='lat')
        ds3=xr.Dataset({'lon':dlon,'lat':dlat})
        if i==0:
            ds4=ds3
        else:
            ds4=xr.concat([ds4,ds3],dim='time')
    ds4['time']=ds2['time']
    ds_save165['time']=ds2['time']
    ds_save135['time']=ds2['time']
    ds4.to_netcdf(adir_data+'biforcation_contour_'+astr_run+'_aviso.nc')
    ds_save165.to_netcdf(adir_data+'biforcation_data165_'+astr_run+'_aviso.nc')
    ds_save135.to_netcdf(adir_data+'biforcation_data135_'+astr_run+'_aviso.nc')
# Out:
# C:\Users\gentemann\Miniconda3\envs\satenv\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# [235.375       42.72879409]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0000.png
# [235.86482751  44.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0001.png
# [235.72606074  44.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0002.png
# [235.72569148  46.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0003.png
# [236.05866088  45.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0004.png
# [235.73156699  44.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0005.png
# [236.00372588  46.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0006.png
# [235.40820433  43.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0007.png
# [236.00640721  39.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0008.png
# [235.375       40.59244237]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0009.png
# [235.625       41.68393725]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0010.png
# [235.6731212  44.625    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0011.png
# [235.70782085  44.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0012.png
# [235.875       45.67831417]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0013.png
# [235.625       40.80970936]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0014.png
# [235.80174272  43.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0015.png
# [235.87355108  43.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0016.png
# [236.06620259  45.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0017.png
# [235.90679171  39.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0018.png
# [235.71183397  41.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0019.png
# [235.86156963  44.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0020.png
# [235.40153921  40.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0021.png
# [235.875       44.93927542]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0022.png
# [235.78129332  40.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0023.png
# [235.47120115  42.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0024.png
# [235.74301179  47.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0025.png
# [235.47570468  47.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0026.png
# [235.53174476  43.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0027.png
# [235.54862918  42.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0028.png
# [237.93697144  36.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0029.png
# [239.125       35.37225233]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0030.png
# [236.875       38.19456413]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0031.png
# [235.875       39.59456928]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0032.png
# [235.8012154  44.375    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0033.png
# [235.375      40.5667143]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0034.png
# [234.125       49.20182151]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0035.png
# [235.9943468  46.375    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0036.png
# [235.48489425  42.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0037.png
# [235.73209765  44.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0038.png
# [235.625       43.87805993]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0039.png
# [235.70647714  43.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0040.png
# [235.875       44.89729196]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0041.png
# [235.42687127  43.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0042.png
# [237.875      36.7887828]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0043.png
# [237.875       36.51792179]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0044.png
# [235.63814174  40.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0045.png
# [235.375       40.50875513]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0046.png
# [235.65144551  41.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0047.png
# [235.81065614  44.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0048.png
# [234.87239021  48.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0049.png
# [235.81371613  46.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0050.png
# [235.875       45.03160246]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0051.png
# [235.87921763  45.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0052.png
# [235.625       46.79492584]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0053.png
# [235.76032342  46.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0054.png
# [236.0579175  45.625    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0055.png
# [235.375       47.71622206]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0056.png
# [235.375       40.60509956]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0057.png
# [235.82074699  41.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0058.png
# [235.52634214  47.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0059.png
# [235.375       42.74637641]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0060.png
# [234.875       48.79594052]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0061.png
# [236.10016502  45.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0062.png
# [235.90945351  46.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0063.png
# [236.030711  46.125   ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0064.png
# [235.56167667  43.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0065.png
# [235.47963873  43.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0066.png
# [235.77040393  40.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0067.png
# [235.47753366  40.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0068.png
# [235.68397419  41.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0069.png
# [235.875       39.86501191]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0070.png
# [236.01449873  45.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0071.png
# [235.76713504  41.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0072.png
# [235.55797681  42.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0073.png
# [235.95252274  45.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0074.png
# [235.93933134  45.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0075.png
# [235.85230406  44.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0076.png
# [236.12485452  46.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0077.png
# [236.09101977  45.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0078.png
# [236.07440501  45.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0079.png
# [235.76180234  41.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0080.png
# [235.625      40.3655321]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0081.png
# [235.76216117  41.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0082.png
# [235.625       43.97775248]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0083.png
# [235.55349458  42.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0084.png
# [233.125       49.79461291]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0085.png
# [235.875       44.90886935]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0086.png
# [235.375       47.53670706]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0087.png
# [235.71719159  43.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0088.png
# [235.99984039  45.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0089.png
# [235.625       41.86615787]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0090.png
# [235.85094197  41.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0091.png
# [235.63381536  41.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0092.png
# [235.625       41.31976693]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0093.png
# [235.375      42.7788296]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0094.png
# [235.64742072  43.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0095.png
# [235.92675092  45.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0096.png
# [235.77102149  40.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0097.png
# [235.67731572  44.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0098.png
# [235.62172088  43.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0099.png
# [236.1067056  45.625    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0100.png
# [235.75803184  44.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0101.png
# [235.7166058  40.875    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0102.png
# [235.875       39.85254088]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0103.png
# [235.375      40.5803971]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0104.png
# [235.625       40.32402222]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0105.png
# [236.0256793  39.875    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0106.png
# [235.83688352  41.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0107.png
# [242.875       32.20484838]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0108.png
# [235.625       41.51651748]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0109.png
# [235.3825627  47.625    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0110.png
# [235.95289165  45.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0111.png
# [236.1186916  45.375    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0112.png
# [235.86457987  44.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0113.png
# [235.41333912  43.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0114.png
# [235.625       40.83886295]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0115.png
# [237.51279082  37.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0116.png
# [237.375       37.64439008]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0117.png
# [236.69719868  38.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0118.png
# [239.16766808  35.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0119.png
# [236.76792618  38.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0120.png
# [235.875       45.56137349]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0121.png
# [235.41154591  42.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0122.png
# [235.50647521  42.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0123.png
# [235.86630627  41.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0124.png
# [235.625       40.82750208]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0125.png
# [235.625       40.85177211]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0126.png
# [235.625       40.70985512]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0127.png
# [235.79164385  40.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0128.png
# [239.33464907  34.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0129.png
# [236.625       38.52025763]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0130.png
# [236.375      38.7354955]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0131.png
# [235.84956573  47.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0132.png
# [234.125       49.33314971]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0133.png
# [235.875       45.54944955]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0134.png
# [235.85332686  46.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0135.png
# [236.1202867  45.125    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0136.png
# [236.02624568  45.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0137.png
# [236.07643502  45.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0138.png
# [237.375       37.76755947]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0139.png
# [235.875       39.60489879]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0140.png
# [236.04282316  45.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0141.png
# [235.625       40.64895168]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0142.png
# [236.20277234  39.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0143.png
# [235.99319411  39.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0144.png
# [234.86509135  48.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0145.png
# [235.57973999  43.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0146.png
# [235.875      45.0134918]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0147.png
# [235.69772255  44.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0148.png
# [235.875       45.12231347]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0149.png
# [236.29768667  39.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0150.png
# [239.11627648  35.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0151.png
# [236.625       38.37518821]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0152.png
# [236.125       39.17193458]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0153.png
# [235.875       39.50127816]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0154.png
# [235.82130553  40.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0155.png
# [235.40364002  42.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0156.png
# [236.02784107  46.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0157.png
# [235.58574224  42.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0158.png
# [235.75507888  43.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0159.png
# [235.61907796  43.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0160.png
# [235.72165767  41.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0161.png
# [235.78672216  41.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0162.png
# [235.625       40.82136106]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0163.png
# [238.375       35.87888408]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0164.png
# [236.29431324  38.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0165.png
# [235.77652952  41.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0166.png
# [236.10510728  45.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0167.png
# [235.625       41.01155579]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0168.png
# [235.12344437  48.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0169.png
# [235.66305282  44.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0170.png
# [235.39131235  43.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0171.png
# [235.80205681  44.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0172.png
# [235.97814293  45.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0173.png
# [235.625       40.68218988]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0174.png
# [235.81976686  40.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0175.png
# [235.375       40.60977015]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0176.png
# [235.625       40.16278974]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0177.png
# [235.875       39.38557466]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0178.png
# [235.625       41.00922144]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0179.png
# [235.80420481  41.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0180.png
# [235.73555839  41.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0181.png
# [235.64921711  41.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0182.png
# [235.64682741  44.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0183.png
# [235.99253656  45.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0184.png
# [235.89723224  46.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0185.png
# [235.82330127  44.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0186.png
# [235.6556063  43.625    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0187.png
# [235.71230613  41.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0188.png
# [235.55766729  43.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0189.png
# [235.625       41.30202908]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0190.png
# [235.375      47.4552902]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0191.png
# [235.625       44.67199475]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0192.png
# [235.65220251  47.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0193.png
# [235.875       45.13387259]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0194.png
# [235.820721  44.625   ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0195.png
# [235.87996882  45.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0196.png
# [235.79847163  43.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0197.png
# [235.787812  43.625   ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0198.png
# [235.53247415  43.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0199.png
# [235.56558101  43.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0200.png
# [235.625       41.45243837]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0201.png
# [235.21184334  48.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0202.png
# [235.375       42.77168141]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0203.png
# [235.50703679  42.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0204.png
# [235.39116219  42.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0205.png
# [235.49218417  47.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0206.png
# [235.875       44.92426529]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0207.png
# [235.77609137  44.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0208.png
# [243.125       31.87362231]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0209.png
# [243.125       31.76521471]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0210.png
# [242.625       32.47188371]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0211.png
# [235.625       40.73534117]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0212.png
# [235.625       41.23474021]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0213.png
# [235.93613948  39.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0214.png
# [235.75512308  40.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0215.png
# [236.01219942  46.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0216.png
# [235.60778542  47.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0217.png
# [235.5759199  47.625    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0218.png
# [236.04937754  46.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0219.png
# [235.875       45.69575761]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0220.png
# [236.12482304  45.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0221.png
# [235.8659867  43.625    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0222.png
# [235.84884717  40.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0223.png
# [235.875       40.06603781]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0224.png
# [235.875       39.77862515]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0225.png
# [236.125       39.35259872]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0226.png
# [235.65729104  44.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0227.png
# [235.875       40.03104719]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0228.png
# [235.66483065  43.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0229.png
# [235.85928294  43.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0230.png
# [235.8711451  44.625    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0231.png
# [235.66755907  43.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0232.png
# [235.65934955  41.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0233.png
# [235.76326394  41.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0234.png
# [235.625       40.84165785]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0235.png
# [235.625       40.27808535]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0236.png
# [235.625       40.90226164]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0237.png
# [235.60855068  42.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0238.png
# [236.00893328  46.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0239.png
# [235.7885338  44.625    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0240.png
# [235.625       43.45536593]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0241.png
# [235.82574967  44.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0242.png
# [235.625       43.42134573]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0243.png
# [235.375       42.88733778]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0244.png
# [235.625       43.51756309]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0245.png
# [235.625       40.77760862]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0246.png
# [235.67574011  40.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0247.png
# [235.71824804  41.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0248.png
# [235.81287993  41.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0249.png
# [235.625       42.03068302]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0250.png
# [235.375       47.56138559]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0251.png
# [235.468473  42.625   ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0252.png
# [235.375       43.36567551]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0253.png
# [235.875       45.28254648]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0254.png
# [235.50657162  43.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0255.png
# [235.50937717  40.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0256.png
# [235.51373065  43.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0257.png
# [237.125      38.1170723]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0258.png
# [236.625       38.60742989]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0259.png
# [236.625       38.57100221]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0260.png
# [236.125       38.91484065]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0261.png
# [235.58319643  42.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0262.png
# [235.5268975  42.625    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0263.png
# [236.07844027  45.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0264.png
# [235.625       43.46162284]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0265.png
# [235.375       42.93849823]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0266.png
# [235.46015962  40.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0267.png
# [235.875       39.85974741]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0268.png
# [236.0492544  39.625    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0269.png
# [235.625       41.03768905]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0270.png
# [235.375       40.51459542]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0271.png
# [235.74657644  41.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0272.png
# [235.625       41.20938086]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0273.png
# [235.66942829  41.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0274.png
# [235.50717073  42.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0275.png
# [235.46581293  42.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0276.png
# [233.875       49.20291473]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0277.png
# [235.625       43.39217218]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0278.png
# [235.75385438  43.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0279.png
# [235.55923655  40.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0280.png
# [237.875      36.7774518]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0281.png
# [236.18371383  39.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0282.png
# [237.375       37.85351905]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0283.png
# [237.27020314  37.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0284.png
# [235.74860406  41.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0285.png
# [233.875       49.36146064]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0286.png
# [235.27063706  48.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0287.png
# [235.61523241  42.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0288.png
# [234.875      48.7504049]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0289.png
# [235.72097772  44.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0290.png
# [235.6147459  43.125    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0291.png
# [236.00053815  45.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0292.png
# [236.02208662  45.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0293.png
# [235.625       40.65241338]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0294.png
# [235.625       40.66873875]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0295.png
# [235.625       40.34113627]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0296.png
# [235.625      40.2625722]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0297.png
# [235.69199545  41.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0298.png
# [235.87254596  43.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0299.png
# [235.74886632  43.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0300.png
# [235.625       44.86951662]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0301.png
# [235.625       44.21674468]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0302.png
# [235.625      43.3763301]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0303.png
# [235.92426976  45.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0304.png
# [235.98119131  45.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0305.png
# [235.66120749  41.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0306.png
# [235.625       41.50512218]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0307.png
# [235.82149896  41.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0308.png
# [235.77947091  41.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0309.png
# [235.375      42.9289986]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0310.png
# [235.60867042  43.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0311.png
# [236.00554088  45.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/_tmp0312.png
# C:\Users\gentemann\Miniconda3\envs\satenv\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# [235.71056364  44.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0000.png
# [235.625       44.65776779]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0001.png
# [235.72146728  43.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0002.png
# [235.625       41.11330605]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0003.png
# [236.09519265  46.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0004.png
# [235.79094029  44.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0005.png
# [235.625       40.84989416]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0006.png
# [235.875       40.09338316]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0007.png
# [235.99242092  46.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0008.png
# [235.875       44.98708724]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0009.png
# [237.375       37.55321082]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0010.png
# [235.625       40.66005712]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0011.png
# [234.125       49.24655261]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0012.png
# [235.625       43.96662346]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0013.png
# [235.62492543  43.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0014.png
# [235.875       39.79230964]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0015.png
# [235.75539067  43.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0016.png
# [235.81110824  44.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0017.png
# [235.43083662  47.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0018.png
# [235.625       41.17645509]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0019.png
# [234.125      49.3134241]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0020.png
# [235.875       45.11764036]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0021.png
# [235.5318159  43.125    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0022.png
# [235.83954848  41.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0023.png
# [235.54995454  43.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0024.png
# [235.875       45.76718677]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0025.png
# [235.96835566  46.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0026.png
# [235.625       40.94255329]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0027.png
# [235.8224332  44.625    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0028.png
# [235.625       44.11585368]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0029.png
# [235.78622179  41.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0030.png
# [235.69015122  40.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0031.png
# [235.66517261  40.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0032.png
# [237.375       37.21447737]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0033.png
# [235.49863677  40.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0034.png
# [235.625       40.68392301]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0035.png
# [235.5565175  42.625    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0036.png
# [236.05022097  46.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0037.png
# [239.375      34.5482352]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0038.png
# [237.41467496  37.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0039.png
# [235.89854681  46.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0040.png
# [235.68948818  43.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0041.png
# [235.65294417  41.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0042.png
# [236.00847957  39.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0043.png
# [233.875      49.2290314]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0044.png
# [235.82755503  46.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0045.png
# [235.799357  40.875   ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0046.png
# [235.57927193  43.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0047.png
# [236.0215686  46.375    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0048.png
# [235.68313866  44.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0049.png
# [239.125       35.07317897]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0050.png
# [236.125       39.09965949]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0051.png
# [235.56409915  42.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0052.png
# [235.875       46.42035345]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0053.png
# [235.74289651  40.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0054.png
# [235.875       39.47188127]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0055.png
# [235.85850527  44.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0056.png
# [235.77322764  44.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0057.png
# [235.97362725  39.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0058.png
# [235.625       40.28495053]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0059.png
# [235.78530825  41.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0060.png
# [235.875       45.00192364]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0061.png
# [235.81830835  44.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0062.png
# [235.61915953  43.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0063.png
# [235.375       42.74478257]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0064.png
# [235.875       46.08745466]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0065.png
# [235.84276693  44.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0066.png
# [235.625       41.79505737]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0067.png
# [233.875       49.21366212]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0068.png
# [236.11762074  45.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0069.png
# [243.125       31.69262204]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0070.png
# [235.625       41.09990493]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0071.png
# [235.7537709  47.125    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0072.png
# [236.10876466  45.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0073.png
# [235.59855209  43.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0074.png
# [235.875       39.72931261]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0075.png
# [236.04674954  45.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0076.png
# [235.625       43.81182686]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0077.png
# [235.625       40.82906167]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0078.png
# [235.625       40.90522089]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0079.png
# [235.625       44.39122834]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0080.png
# [235.76931566  43.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0081.png
# [235.625       41.09113567]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0082.png
# [235.375       42.52649603]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0083.png
# [235.375       42.63102625]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0084.png
# [235.74526154  43.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0085.png
# [235.98674787  39.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0086.png
# [236.125       38.90347715]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0087.png
# [235.56613061  42.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0088.png
# [235.53067207  40.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0089.png
# [235.625       40.72044458]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0090.png
# [235.625       41.94765509]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0091.png
# [234.51577602  48.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0092.png
# [236.08384432  45.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0093.png
# [237.375       37.24805581]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0094.png
# [235.875       40.03823465]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0095.png
# [234.125       49.37358441]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0096.png
# [235.95344681  45.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0097.png
# [235.625       40.81580671]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0098.png
# [235.8618609  40.875    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0099.png
# [235.875       45.17651022]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0100.png
# [235.625       44.35673915]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0101.png
# [235.40984989  43.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0102.png
# [235.375       42.52425855]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0103.png
# [235.76315237  43.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/quarterly/_tmp0104.png
# C:\Users\gentemann\Miniconda3\envs\satenv\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# [235.875      44.8951026]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0000.png
# [235.77902234  41.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0001.png
# [235.45164501  43.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0002.png
# [235.81185518  44.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0003.png
# [235.69046684  46.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0004.png
# [235.75485821  43.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0005.png
# [235.4254374  43.125    ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0006.png
# [235.375       42.62333652]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0007.png
# [235.39474155  40.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0008.png
# [235.88790334  39.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0009.png
# [235.96389588  39.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0010.png
# [235.86290234  44.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0011.png
# [235.625      40.2389936]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0012.png
# [235.375       42.70235566]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0013.png
# [235.375      40.6201959]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0014.png
# [235.57732724  43.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0015.png
# [235.86118334  44.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0016.png
# [235.86480234  44.875     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0017.png
# [235.625       43.55050911]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0018.png
# [235.625      41.2482303]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0019.png
# [235.46317583  43.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0020.png
# [235.375      40.5953987]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0021.png
# [235.625       40.87183915]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0022.png
# [235.625       41.77354253]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0023.png
# [235.75031997  44.375     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0024.png
# [235.72455932  43.625     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0025.png
# [236.00554088  45.125     ]
# F:/data/NASA_biophysical/biforcation_figures_chelle/figs/annual/_tmp0026.png

# %%
ds2

# %%
astr_run='monthly'
adir_figs='F:/data/NASA_biophysical/biforcation_figures_chelle/figs/monthly/'
ds2 = ds.resample(time='M',keep_attrs=True).mean(skipna=False)
ds2.gosu.sel(lon=-165.125,lat=slice(30,60)).plot()

# %%
#make images of contours on a map
import matplotlib
from matplotlib import cm
from numpy import linspace
from matplotlib import pyplot as plt
import cartopy.crs as ccrs
ds4=xr.open_dataset(adir_data+'biforcation_contour_annual_aviso.nc')
fig = plt.figure(figsize=(18,3.5))
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
dir_figs='F:/data/NASA_biophysical/biforcation_figures_chelle/figs/'
start,stop,number_of_lines = 0.0,1.0,27
norm = matplotlib.colors.Normalize(vmin=1992,vmax=2020)
c_m = matplotlib.cm.jet
# create a ScalarMappable and initialize a data structure
s_m = plt.cm.ScalarMappable(cmap=c_m, norm=norm)
s_m.set_array([])
for i in range(ds4.time.size):
    ii=1992+i
    ax.plot(ds4.lon[i,:],ds4.lat[i,:],color=s_m.to_rgba(ii),transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_extent([130,250,30,40])
cb=plt.colorbar(s_m,fraction=.1)
fig.savefig(dir_figs + 'all_annual.png', dpi=300)
ds4=xr.open_dataset(adir_data+'biforcation_contour_quarterly_aviso.nc')

fig = plt.figure(figsize=(18,3.5))
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
dir_figs='F:/data/NASA_biophysical/biforcation_figures_chelle/figs/'
start,stop,number_of_lines = 0.0,1.0,27
norm = matplotlib.colors.Normalize(vmin=1992,vmax=2020)
c_m = matplotlib.cm.jet
# create a ScalarMappable and initialize a data structure
s_m = plt.cm.ScalarMappable(cmap=c_m, norm=norm)
s_m.set_array([])
for i in range(ds4.time.size):
    ii=1992+i/4.
    ax.plot(ds4.lon[i,:],ds4.lat[i,:],color=s_m.to_rgba(ii),transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_extent([130,250,30,40])
cb=plt.colorbar(s_m,fraction=.1)
fig.savefig(dir_figs + 'all_quarterly.png', dpi=300)
fig.savefig(dir_figs + 'all_annual.png', dpi=300)

ds4=xr.open_dataset(adir_data+'biforcation_contour_monthly_aviso.nc')
fig = plt.figure(figsize=(18,3.5))
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
dir_figs='F:/data/NASA_biophysical/biforcation_figures_chelle/figs/'
start,stop,number_of_lines = 0.0,1.0,27
norm = matplotlib.colors.Normalize(vmin=1992,vmax=2020)
c_m = matplotlib.cm.jet
# create a ScalarMappable and initialize a data structure
s_m = plt.cm.ScalarMappable(cmap=c_m, norm=norm)
s_m.set_array([])
for i in range(ds4.time.size):
    ii=1992+i/12.
    ax.plot(ds4.lon[i,:],ds4.lat[i,:],color=s_m.to_rgba(ii),transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_extent([130,250,30,40])
cb=plt.colorbar(s_m,fraction=.1)
fig.savefig(dir_figs + 'all_monthly.png', dpi=300)

# %%
#test annual data
tem = ds.adt[0:400,:,:].resample(time='AS-JAN',keep_attrs=True).mean(skipna=False)
print(tem[0,360,720].load())
tem2 = ds.adt[0:365,:,:].mean({'time'},skipna=False)
print(tem2[360,720].load())

# %%
#test quarterly data
tem = ds.adt[300:450,:,:].resample(time='QS-DEC',keep_attrs=True).mean(skipna=False)
print(tem[0,360,720].load())
print(tem[1,360,720].load())
tem2 = ds.adt[334:424,:,:].mean({'time'},skipna=False)
print(tem2[360,720].load())

# %%
print(ds.time[334].data)
ds.time[424].data

# %%
import xarray as xr
adir_data='F:/data/NASA_biophysical/biforcation_figures_chelle/'
ds=xr.open_dataset(adir_data+'biforcation_data135_quarterly_aviso.nc')
adir_figs='F:/data/NASA_biophysical/biforcation_figures_chelle/figs/'
fig = plt.figure(figsize=(8,5))
ds.lat.plot()
fig.savefig(adir_figs + 'all135_lat_quarterly2.png', dpi=300)

# %%
def get_center_kathleen(rlon):
    if rlon==-165:
        ds_lon = xr.open_dataset('F:/data/NASA_biophysical/timeseries_data/MonthlyBifurcationLat165.nc')
    if rlon==-135:
        ds_lon = xr.open_dataset('F:/data/NASA_biophysical/timeseries_data/MonthlyBifurcationLat135.nc')
    ds_lon['month']=np.ceil((ds_lon.year-ds_lon.year.astype('int'))*12).astype('int')
    ds_lon['iyear']=ds_lon.year.astype('int')
    ds_lon = ds_lon.assign_coords(yr=ds_lon.year)
    ds_lon = ds_lon.assign_coords(iyear=ds_lon.iyear)
    ds_lon = ds_lon.assign_coords(month=ds_lon.month)
    ds_out = ds_lon.copy(deep=True)    
    tt=[]
    for i in range(276):
        dtem=np.datetime64(str(ds_out.iyear[i].data)+'-'+str(ds_out.month[i].data).zfill(2))
        tt.append(dtem)
    ds_out['yr']=tt
    ds_lon.close()
    return ds_out
def get_center_chelle(rlon):
    adir_data='F:/data/NASA_biophysical/biforcation_figures_chelle/'
    if rlon==-165:
        ds=xr.open_dataset(adir_data+'biforcation_data165_monthly_aviso.nc')
    if rlon==-135:
        ds=xr.open_dataset(adir_data+'biforcation_data135_monthly_aviso.nc')
    ds.close()
    return ds
for ilat in range(135,166,30):
    ds2=get_center_kathleen(-1*ilat)
    ds=get_center_chelle(-1*ilat)
    adir_figs='F:/data/NASA_biophysical/biforcation_figures_chelle/figs/'
    fig = plt.figure(figsize=(8,5))
    ax=ds.lat.plot(label='chelle')
    ax=ds2.latitude.plot(label='kath')
    #plt.plot(ds2.yr,ds2.latitude)
    fig.legend()
    fig.savefig(adir_figs + 'all'+str(ilat)+'_lat_both_monthly2.png', dpi=300)
