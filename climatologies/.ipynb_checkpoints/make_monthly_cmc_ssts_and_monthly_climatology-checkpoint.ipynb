# %%
import pandas
import matplotlib as mpl
import xarray as xr
import numpy as np
import datetime as dt
dir_cmc='F:/data/sst/cmc/CMC0.2deg/v2/'
dir_cmc_clim='F:/data/sst/cmc/CMC0.2deg/v2/climatology/'
def get_filename(lyr,idyjl):
    d = dt.date(lyr,1,1) + dt.timedelta(idyjl - 1)
    dir_cmc='F:/data/sst/cmc/CMC0.2deg/v2/'
    syr=str(d.year).zfill(4)
    smon=str(d.month).zfill(2)
    sdym=str(d.day).zfill(2)
    sjdy=str(idyjl).zfill(3)
    fname_tem=syr + smon + sdym + '120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
    cmc_filename = dir_cmc + syr + '/' + sjdy + '/' + fname_tem
    return cmc_filename
def get_filename_v2a(lyr,idyjl):
    d = dt.date(lyr,1,1) + dt.timedelta(idyjl - 1)
    dir_cmc='F:/data/sst/cmc/CMC0.2deg/v2/'
    syr=str(d.year).zfill(4)
    smon=str(d.month).zfill(2)
    sdym=str(d.day).zfill(2)
    sjdy=str(idyjl).zfill(3)
    fname_tem=syr + smon + sdym + '120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv03.0.nc'
    cmc_filename = dir_cmc + syr + '/' + sjdy + '/' + fname_tem
    return cmc_filename
def get_filename_v2a_dir(lyr,idyjl):
    d = dt.date(lyr,1,1) + dt.timedelta(idyjl - 1)
    dir_cmc='F:/data/sst/cmc/CMC0.2deg/v2/'
    syr=str(d.year).zfill(4)
    smon=str(d.month).zfill(2)
    sdym=str(d.day).zfill(2)
    sjdy=str(idyjl).zfill(3)
    cmc_filename = dir_cmc + syr + '/' + sjdy + '/' 
    return cmc_filename
def get_filename_v3(lyr,idyjl):
    d = dt.date(lyr,1,1) + dt.timedelta(idyjl - 1)
    dir_cmc='F:/data/sst/cmc/CMC0.1deg/v3/'
    syr=str(d.year).zfill(4)
    smon=str(d.month).zfill(2)
    sdym=str(d.day).zfill(2)
    sjdy=str(idyjl).zfill(3)
    fname_tem=syr + smon + sdym + '120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc'
    cmc_filename = dir_cmc + syr + '/' + sjdy + '/' + fname_tem
    return cmc_filename

# %%
#make cmc monthly average ssts
for lyr in range(1992,2017): #2017):
    ds_mnth=[]
    for imon in range(1,13):
        init = 0
        for idyjl in range(1,366):
            d = dt.date(lyr,1,1) + dt.timedelta(idyjl - 1)
            if d.month!=imon:
                continue
            cmc_filename = get_filename(lyr,idyjl)
            print(cmc_filename)
            ds = xr.open_dataset(cmc_filename,drop_variables=['analysis_error','sea_ice_fraction'])
            ds_masked = ds.where(ds['mask'] == 1.) 
            ds.close()
            ds_masked['sq_sst']=ds_masked.analysed_sst**2
            if init==0:
                ds_sum = ds_masked
                init = 1
            else:
                ds_sum = xr.concat([ds_sum,ds_masked],dim = 'time')
            print(idyjl,ds_sum.dims)
        ds_clim2 = ds_sum.resample(time='M').mean()    
#        ds_clim2 = ds_sum.groupby('time.month').mean('time')
        #ds_sum = ds_sum.mean('time',skipna=True)
        ds_mnth.append(ds_clim2)
    combined = xr.concat(ds_mnth, dim='time')
    fname_tem='monthly/' + str(lyr) + 'monthly_average_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
    cmc_filename_out = dir_cmc + fname_tem
    combined.to_netcdf(cmc_filename_out)

# %%
#make cmc monthly average ssts FOR 0.1 deg data
#first read in 0.2 deg grid to interpolate onto

#testing 0.1 CMC
filename = 'F:/data/sst/cmc/CMC0.2deg/v2/1992/011/19920111120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
ds_v2 = xr.open_dataset(filename)
new_lat = np.linspace(ds_v2.lat[0], ds_v2.lat[-1], ds_v2.dims['lat'])
new_lon = np.linspace(ds_v2.lon[0], ds_v2.lon[-1], ds_v2.dims['lon'])

for lyr in range(2017,2019): #2017):
    ds_mnth=[]
    for imon in range(1,13):
        init = 0
        for idyjl in range(1,366):
            d = dt.date(lyr,1,1) + dt.timedelta(idyjl - 1)
            if d.month!=imon:
                continue
            cmc_filename = get_filename_v3(lyr,idyjl)
            print(cmc_filename)
            ds = xr.open_dataset(cmc_filename,drop_variables=['analysis_error','sea_ice_fraction'])
            ds_masked = ds.where(ds['mask'] == 1.) 
            ds_masked['sq_sst']=ds_masked.analysed_sst**2
            ds_interp = ds_masked.interp(lat = new_lat,lon = new_lon)            
            ds.close()
            if init==0:
                ds_sum = ds_interp
                init = 1
            else:
                ds_sum = xr.concat([ds_sum,ds_interp],dim = 'time')
            #print(idyjl,ds_sum.dims)
        ds_clim2 = ds_sum.resample(time='M').mean()    
#        ds_clim2 = ds_sum.groupby('time.month').mean('time')
        #ds_sum = ds_sum.mean('time',skipna=True)
        ds_mnth.append(ds_clim2)
    combined = xr.concat(ds_mnth, dim='time')
    fname_tem='monthly/' + str(lyr) + 'monthly_average_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
    cmc_filename_out = dir_cmc + fname_tem
    combined.to_netcdf(cmc_filename_out)

# %%
#need to convert 2017 and 2018 to float 32 otherwise they don't combine with other index nicely
#testing data files 
file1='F:/data/sst/cmc/CMC0.2deg/v2/monthly/2016monthly_average_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
file2='F:/data/sst/cmc/CMC0.2deg/v2/monthly/2017monthly_average_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
ds1=xr.open_dataset(file1)
ds2=xr.open_dataset(file2)
ds1.close()
ds2.close()
ds3 = ds2.astype('float32')
ds3['lon']=ds1.lon
ds3['lat']=ds1.lat
file2='F:/data/sst/cmc/CMC0.2deg/v2/monthly/2017monthly_average_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
ds3.to_netcdf(file2)

#need to convert 2017 and 2018 to float 32 otherwise they don't combine with other index nicely
#testing data files 
file1='F:/data/sst/cmc/CMC0.2deg/v2/monthly/2016monthly_average_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
file2='F:/data/sst/cmc/CMC0.2deg/v2/monthly/2018monthly_average_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
ds1=xr.open_dataset(file1)
ds2=xr.open_dataset(file2)
ds1.close()
ds2.close()
ds3 = ds2.astype('float32')
ds3['lon']=ds1.lon
ds3['lat']=ds1.lat
file2='F:/data/sst/cmc/CMC0.2deg/v2/monthly/2018monthly_average_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
ds3.to_netcdf(file2)

# %%
#testing data files 
file1='F:/data/sst/cmc/CMC0.2deg/v2/monthly/2016monthly_average_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
file2='F:/data/sst/cmc/CMC0.2deg/v2/monthly/2018monthly_average_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
ds1=xr.open_dataset(file1)
ds2=xr.open_dataset(file2)
ds3 = ds2.astype('float32')
ds3['lon']=ds1.lon
ds3['lat']=ds1.lat
#print(ds3)
ds1.close()
ds2.close()
ds3 = xr.concat([ds3,ds1],dim = 'time')
print(ds3)

# %%
#make cmc climatology from monthly files
for icase in range(0,3):
    if icase==0:
        iyr1,iyr2 = 1992,2000
    if icase==1:
        iyr1,iyr2 = 2000,2010
    if icase==2:
        iyr1,iyr2 = 2010,2019
    init = 0
    for lyr in range(iyr1,iyr2): 
        fname_tem='monthly/' + str(lyr) + 'monthly_average_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
        cmc_filename_out = dir_cmc + fname_tem
        ds = xr.open_dataset(cmc_filename_out)
        ds_masked = ds.where(ds['mask'] == 1.) 
        if init==0:
            ds_sum = ds_masked
            init = 1
        else:
            ds_sum = xr.concat([ds_sum,ds_masked],dim = 'time')
        print(lyr,ds_sum.dims)
    ds_sum2 = ds_sum.groupby('time.month').mean('time')
    fname_tem='monthly/monthly_climatology_'+str(iyr1)+'_'+str(iyr2-1)+'_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
    cmc_filename_out = dir_cmc + fname_tem
    ds_sum2.to_netcdf(cmc_filename_out)
# Out:
# 1992 Frozen(SortedKeysDict({'time': 12, 'lat': 901, 'lon': 1800}))
# 1993 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 24}))
# 1994 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 36}))
# 1995 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 48}))
# 1996 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 60}))
# 1997 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 72}))
# 1998 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 84}))
# 1999 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 96}))
# C:\Users\gentemann\Miniconda3\envs\satenv\lib\site-packages\xarray\core\nanops.py:159: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# 2000 Frozen(SortedKeysDict({'time': 12, 'lat': 901, 'lon': 1800}))
# 2001 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 24}))
# 2002 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 36}))
# 2003 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 48}))
# 2004 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 60}))
# 2005 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 72}))
# 2006 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 84}))
# 2007 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 96}))
# 2008 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 108}))
# 2009 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 120}))
# C:\Users\gentemann\Miniconda3\envs\satenv\lib\site-packages\xarray\core\nanops.py:159: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# 2010 Frozen(SortedKeysDict({'time': 12, 'lat': 901, 'lon': 1800}))
# 2011 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 24}))
# 2012 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 36}))
# 2013 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 48}))
# 2014 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 60}))
# 2015 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 72}))
# 2016 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 84}))
# 2017 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 96}))
# 2018 Frozen(SortedKeysDict({'lat': 901, 'lon': 1800, 'time': 108}))
# C:\Users\gentemann\Miniconda3\envs\satenv\lib\site-packages\xarray\core\nanops.py:159: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)

# %%
num_year = 2018-1992+1
num_year_file1 = 1999 - 1992 +1
num_year_file2 = 2009 - 2000 +1 
num_year_file3 = 2018 - 2010 +1
frac_file1 = num_year_file1 / num_year
frac_file2 = num_year_file2 / num_year
frac_file3 = num_year_file3 / num_year
fname_tem=dir_cmc + 'monthly/monthly_climatology_1992_1999_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
print(fname_tem)
ds = xr.open_dataset(fname_tem)
ds_masked = ds.where(ds['mask'] == 1.) 
ds.close()
fname_tem=dir_cmc + 'monthly/monthly_climatology_2000_2009_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
print(fname_tem)
ds = xr.open_dataset(fname_tem)
ds_masked2 = ds.where(ds['mask'] == 1.) 
#ds_sum = xr.concat([ds_masked2,ds_masked],dim = 'time')
ds.close()
fname_tem=dir_cmc + 'monthly/monthly_climatology_2010_2018_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
print(fname_tem)
ds = xr.open_dataset(fname_tem)
ds_masked3 = ds.where(ds['mask'] == 1.) 
#ds_sum = xr.concat([ds_masked2,ds_masked],dim = 'time')
ds.close()
ds_ave = frac_file1*ds_masked + frac_file2*ds_masked2 + frac_file3*ds_masked3
#ds_sum = ds_sum.mean('time',skipna=True)
print(frac_file1+frac_file2+frac_file3,frac_file1,frac_file2,frac_file3)
fname_tem=dir_cmc + 'monthly/monthly_climatology_1992_2018_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
print(fname_tem)
ds_ave.to_netcdf(fname_tem)
# Out:
# F:/data/sst/cmc/CMC0.2deg/v2/monthly/monthly_climatology_1992_1999_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc
# F:/data/sst/cmc/CMC0.2deg/v2/monthly/monthly_climatology_2000_2009_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc
# F:/data/sst/cmc/CMC0.2deg/v2/monthly/monthly_climatology_2010_2018_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc
# 1.0 0.2962962962962963 0.37037037037037035 0.3333333333333333
# F:/data/sst/cmc/CMC0.2deg/v2/monthly/monthly_climatology_1992_2018_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc

# %%
num_year = 2018-2000+1
#num_year_file1 = 1999 - 1992 +1
num_year_file2 = 2009 - 2000 +1 
num_year_file3 = 2018 - 2010 +1
#frac_file1 = num_year_file1 / num_year
frac_file2 = num_year_file2 / num_year
frac_file3 = num_year_file3 / num_year
#fname_tem=dir_cmc + 'monthly/monthly_climatology_1992_1999_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
#print(fname_tem)
#ds = xr.open_dataset(fname_tem)
#ds_masked = ds.where(ds['mask'] == 1.) 
#ds.close()
fname_tem=dir_cmc + 'monthly/monthly_climatology_2000_2009_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
print(fname_tem)
ds = xr.open_dataset(fname_tem)
ds_masked2 = ds.where(ds['mask'] == 1.) 
#ds_sum = xr.concat([ds_masked2,ds_masked],dim = 'time')
ds.close()
fname_tem=dir_cmc + 'monthly/monthly_climatology_2010_2018_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
print(fname_tem)
ds = xr.open_dataset(fname_tem)
ds_masked3 = ds.where(ds['mask'] == 1.) 
#ds_sum = xr.concat([ds_masked2,ds_masked],dim = 'time')
ds.close()
ds_ave = frac_file2*ds_masked2 + frac_file3*ds_masked3
#ds_sum = ds_sum.mean('time',skipna=True)
print(frac_file2+frac_file3,frac_file2,frac_file3)
fname_tem=dir_cmc + 'monthly/monthly_climatology_2000_2018_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
print(fname_tem)
ds_ave.to_netcdf(fname_tem)
# Out:
# F:/data/sst/cmc/CMC0.2deg/v2/monthly/monthly_climatology_2000_2009_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc
# F:/data/sst/cmc/CMC0.2deg/v2/monthly/monthly_climatology_2010_2018_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc
# 1.0 0.5263157894736842 0.47368421052631576
# F:/data/sst/cmc/CMC0.2deg/v2/monthly/monthly_climatology_2000_2018_120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc

# %%
#make daily 0.2 deg cmc files
#make cmc monthly average ssts FOR 0.1 deg data
#first read in 0.2 deg grid to interpolate onto

#20170101120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc
import os
#testing 0.1 CMC
filename = 'F:/data/sst/cmc/CMC0.2deg/v2/1992/011/19920111120000-CMC-L4_GHRSST-SSTfnd-CMC0.2deg-GLOB-v02.0-fv02.0.nc'
ds_v2 = xr.open_dataset(filename)
new_lat = np.linspace(ds_v2.lat[0], ds_v2.lat[-1], ds_v2.dims['lat'])
new_lon = np.linspace(ds_v2.lon[0], ds_v2.lon[-1], ds_v2.dims['lon'])

for lyr in range(2017,2019): #2017):
    for idyjl in range(1,366):
        cmc_filename = get_filename_v3(lyr,idyjl)
        print(cmc_filename)
        ds = xr.open_dataset(cmc_filename,drop_variables=['analysis_error','sea_ice_fraction'])
        ds_masked = ds.where(ds['mask'] == 1.) 
        ds_interp = ds_masked.interp(lat = new_lat,lon = new_lon)            
        ds.close()
        cmc_filename_out = get_filename_v2a(lyr,idyjl)
        cmc_dir = get_filename_v2a_dir(lyr,idyjl)
        if not os.path.exists(cmc_dir):
            os.mkdir(cmc_dir)
        ds.to_netcdf(cmc_filename_out)
# Out:
# F:/data/sst/cmc/CMC0.1deg/v3/2017/001/20170101120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/002/20170102120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/003/20170103120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/004/20170104120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/005/20170105120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/006/20170106120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/007/20170107120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/008/20170108120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/009/20170109120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/010/20170110120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/011/20170111120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/012/20170112120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/013/20170113120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/014/20170114120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/015/20170115120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/016/20170116120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/017/20170117120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/018/20170118120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/019/20170119120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/020/20170120120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/021/20170121120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/022/20170122120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/023/20170123120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/024/20170124120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/025/20170125120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/026/20170126120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/027/20170127120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/028/20170128120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/029/20170129120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/030/20170130120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/031/20170131120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/032/20170201120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/033/20170202120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/034/20170203120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/035/20170204120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/036/20170205120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/037/20170206120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/038/20170207120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/039/20170208120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/040/20170209120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/041/20170210120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/042/20170211120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/043/20170212120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/044/20170213120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/045/20170214120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/046/20170215120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/047/20170216120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/048/20170217120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/049/20170218120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/050/20170219120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/051/20170220120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/052/20170221120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/053/20170222120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/054/20170223120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/055/20170224120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/056/20170225120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/057/20170226120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/058/20170227120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/059/20170228120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/060/20170301120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/061/20170302120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/062/20170303120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/063/20170304120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/064/20170305120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/065/20170306120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/066/20170307120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/067/20170308120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/068/20170309120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/069/20170310120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/070/20170311120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/071/20170312120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/072/20170313120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/073/20170314120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/074/20170315120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/075/20170316120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/076/20170317120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/077/20170318120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/078/20170319120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/079/20170320120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/080/20170321120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/081/20170322120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/082/20170323120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/083/20170324120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/084/20170325120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/085/20170326120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/086/20170327120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/087/20170328120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/088/20170329120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/089/20170330120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/090/20170331120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/091/20170401120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/092/20170402120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/093/20170403120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/094/20170404120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/095/20170405120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/096/20170406120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/097/20170407120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/098/20170408120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/099/20170409120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/100/20170410120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/101/20170411120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/102/20170412120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/103/20170413120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/104/20170414120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/105/20170415120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/106/20170416120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/107/20170417120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/108/20170418120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/109/20170419120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/110/20170420120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/111/20170421120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/112/20170422120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/113/20170423120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/114/20170424120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/115/20170425120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/116/20170426120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/117/20170427120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/118/20170428120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/119/20170429120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/120/20170430120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/121/20170501120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/122/20170502120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/123/20170503120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/124/20170504120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/125/20170505120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/126/20170506120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/127/20170507120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/128/20170508120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/129/20170509120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/130/20170510120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/131/20170511120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/132/20170512120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/133/20170513120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/134/20170514120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/135/20170515120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/136/20170516120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/137/20170517120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/138/20170518120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/139/20170519120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/140/20170520120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/141/20170521120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/142/20170522120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/143/20170523120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/144/20170524120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/145/20170525120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/146/20170526120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/147/20170527120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/148/20170528120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/149/20170529120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/150/20170530120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/151/20170531120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/152/20170601120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/153/20170602120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/154/20170603120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/155/20170604120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/156/20170605120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/157/20170606120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/158/20170607120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/159/20170608120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/160/20170609120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/161/20170610120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/162/20170611120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/163/20170612120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/164/20170613120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/165/20170614120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/166/20170615120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/167/20170616120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/168/20170617120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/169/20170618120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/170/20170619120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/171/20170620120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/172/20170621120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/173/20170622120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/174/20170623120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/175/20170624120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/176/20170625120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/177/20170626120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/178/20170627120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/179/20170628120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/180/20170629120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/181/20170630120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/182/20170701120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/183/20170702120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/184/20170703120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/185/20170704120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/186/20170705120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/187/20170706120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/188/20170707120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/189/20170708120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/190/20170709120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/191/20170710120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/192/20170711120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/193/20170712120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/194/20170713120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/195/20170714120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/196/20170715120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/197/20170716120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/198/20170717120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/199/20170718120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/200/20170719120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/201/20170720120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/202/20170721120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/203/20170722120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/204/20170723120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/205/20170724120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/206/20170725120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/207/20170726120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/208/20170727120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/209/20170728120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/210/20170729120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/211/20170730120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/212/20170731120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/213/20170801120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/214/20170802120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/215/20170803120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/216/20170804120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/217/20170805120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/218/20170806120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/219/20170807120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/220/20170808120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/221/20170809120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/222/20170810120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/223/20170811120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/224/20170812120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/225/20170813120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/226/20170814120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/227/20170815120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/228/20170816120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/229/20170817120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/230/20170818120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/231/20170819120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/232/20170820120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/233/20170821120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/234/20170822120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/235/20170823120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/236/20170824120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/237/20170825120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/238/20170826120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/239/20170827120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/240/20170828120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/241/20170829120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/242/20170830120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/243/20170831120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/244/20170901120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/245/20170902120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/246/20170903120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/247/20170904120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/248/20170905120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/249/20170906120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/250/20170907120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/251/20170908120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/252/20170909120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/253/20170910120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/254/20170911120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/255/20170912120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/256/20170913120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/257/20170914120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/258/20170915120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/259/20170916120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/260/20170917120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/261/20170918120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/262/20170919120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/263/20170920120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/264/20170921120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/265/20170922120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/266/20170923120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/267/20170924120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/268/20170925120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/269/20170926120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/270/20170927120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/271/20170928120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/272/20170929120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/273/20170930120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/274/20171001120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/275/20171002120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/276/20171003120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/277/20171004120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/278/20171005120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/279/20171006120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/280/20171007120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/281/20171008120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/282/20171009120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/283/20171010120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/284/20171011120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/285/20171012120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/286/20171013120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/287/20171014120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/288/20171015120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/289/20171016120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/290/20171017120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/291/20171018120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/292/20171019120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/293/20171020120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/294/20171021120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/295/20171022120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/296/20171023120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/297/20171024120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/298/20171025120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/299/20171026120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/300/20171027120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/301/20171028120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/302/20171029120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/303/20171030120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/304/20171031120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/305/20171101120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/306/20171102120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/307/20171103120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/308/20171104120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/309/20171105120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/310/20171106120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/311/20171107120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/312/20171108120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/313/20171109120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/314/20171110120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/315/20171111120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/316/20171112120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/317/20171113120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/318/20171114120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/319/20171115120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/320/20171116120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/321/20171117120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/322/20171118120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/323/20171119120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/324/20171120120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/325/20171121120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/326/20171122120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/327/20171123120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/328/20171124120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/329/20171125120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/330/20171126120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/331/20171127120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/332/20171128120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/333/20171129120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/334/20171130120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/335/20171201120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/336/20171202120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/337/20171203120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/338/20171204120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/339/20171205120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/340/20171206120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/341/20171207120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/342/20171208120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/343/20171209120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/344/20171210120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/345/20171211120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/346/20171212120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/347/20171213120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/348/20171214120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/349/20171215120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/350/20171216120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/351/20171217120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/352/20171218120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/353/20171219120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/354/20171220120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/355/20171221120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/356/20171222120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/357/20171223120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/358/20171224120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/359/20171225120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/360/20171226120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/361/20171227120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/362/20171228120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/363/20171229120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/364/20171230120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2017/365/20171231120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# F:/data/sst/cmc/CMC0.1deg/v3/2018/001/20180101120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-34f84486d5d3> in <module>
#      22         cmc_dir = get_filename_v2a_dir(lyr,idyjl)
#      23         if not os.path.exists(cmc_dir):
# ---> 24             os.mkdir(cmc_dir)
#      25         ds.to_netcdf(cmc_filename_out)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'F:/data/sst/cmc/CMC0.2deg/v2/2018/001/'
